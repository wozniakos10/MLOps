# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Learning objectives
#
# 1. **Implement automated experiment tracking** using MLflow autologging capabilities with scikit-learn, enabling automatic capture of model parameters and metrics without writing additional tracking code.
#
# 2. **Configure manual logging strategies** for PyTorch experiments, implementing custom tracking for metrics, parameters, and artifacts throughout the training process.
#
# 3. **Analyze and compare experimental results** using MLflow tracking UI and programmatic APIs to identify optimal model configurations and understand performance patterns.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration

# %% [markdown]
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.

# %% [markdown]
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5000
# ```
# Important: Keep this terminal window open. The MLflow server will continue running and be accessible at http://localhost:5000

# %% [markdown]
# To verify if the server runs properly, let's connect to git:

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:8080")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:8080

# %% [markdown]
# Setup complete! You now have the MLflow server running as a separate process, and `mlflow` library in this Jupyter Notebook is connected to it. Just note that we had to use the proper host and port - if you want to connect to a remote server, modify the tracking URI appropriately.

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here. As we have temporal data, the best way to evaluate our model is time (chronological) split, where the newest data is used for testing. We will assume that we have the data for years 2006 and 2007, and evaluate using data from 2008.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("lab_data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a buch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# <Experiment: artifact_location='/Users/dawidwozniak/studies/sem9/MLOps/lab05/laboratory/mlflow-artifacts/1', creation_time=1762336990759, experiment_id='1', last_update_time=1762336990759, lifecycle_stage='active', name='ames-housing-autolog', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor


models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score, mean_squared_error


def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:00:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.895 ± 0.035
# 🏃 View run Ridge Regression at: http://localhost:8080/#/experiments/1/runs/cb38432366474fd491d0f4c3e1e1e0db
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
#
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.755 ± 0.057
# 🏃 View run Decision Tree at: http://localhost:8080/#/experiments/1/runs/216b228631d44ff0a5cf1dde5f315b93
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
# 2025/11/09 17:01:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38324.60
#   MAE: 26033.27
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.691 ± 0.049
# 🏃 View run K-Nearest Neighbors at: http://localhost:8080/#/experiments/1/runs/f2078f6be0b94f4f9ddf5a01574de515
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
# 2025/11/09 17:01:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25814.13
#   MAE: 15606.16
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
# 🏃 View run Random Forest at: http://localhost:8080/#/experiments/1/runs/de83990dfb1f4f21abd1823a40a33b48
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
# 2025/11/09 17:01:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gradient Boosting:
#   RMSE: 21600.50
#   MAE: 13840.01
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.904 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:8080/#/experiments/1/runs/8d8458b7ea5f4370a2dceca93d5248f2
# 🧪 View experiment at: http://localhost:8080/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Since we obtained quite satisfactory results, our imaginary client would like to be sure that we do our best and wants us to compare many more combinations.
#
# Your task is to run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
#
# Did you manage to beat the previous approaches?

# %%
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.ensemble import ExtraTreesRegressor, AdaBoostRegressor
from sklearn.svm import SVR

# %%
new_models = [
    ("Lasso Regression", Lasso(alpha=0.1, random_state=42)),
    ("ElasticNet", ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)),
    ("Extra Trees", ExtraTreesRegressor(n_estimators=150, max_depth=15, random_state=42)),
    ("AdaBoost", AdaBoostRegressor(n_estimators=100, learning_rate=0.1, random_state=42)),
    ("Support Vector Regression", SVR(kernel='rbf', C=100, epsilon=0.1))
]
fit_sklearn_models_with_cv(new_models, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Lasso Regression:
#   RMSE: 24077.53
#   MAE: 16759.25
#   R^2: 0.899
#   CV R^2 (mean ± std): 0.867 ± 0.074
# 🏃 View run Lasso Regression at: http://localhost:8080/#/experiments/1/runs/0a51e030e3d34d2080001d4c7b9e6bcb
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
#
# ElasticNet:
#   RMSE: 27319.47
#   MAE: 18594.52
#   R^2: 0.869
#   CV R^2 (mean ± std): 0.843 ± 0.027
# 🏃 View run ElasticNet at: http://localhost:8080/#/experiments/1/runs/c778419d6e4a476bb42d87be6bebe19b
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
# 2025/11/09 17:01:09 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:10 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Extra Trees:
#   RMSE: 23228.10
#   MAE: 14989.03
#   R^2: 0.906
#   CV R^2 (mean ± std): 0.889 ± 0.042
# 🏃 View run Extra Trees at: http://localhost:8080/#/experiments/1/runs/cfd2513865b040b6bee44381c9738ae1
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
# 2025/11/09 17:01:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:16 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:16 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:16 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# AdaBoost:
#   RMSE: 32868.06
#   MAE: 22434.70
#   R^2: 0.811
#   CV R^2 (mean ± std): 0.818 ± 0.059
# 🏃 View run AdaBoost at: http://localhost:8080/#/experiments/1/runs/0f59c86377e345c08fbe618b9e274fcb
# 🧪 View experiment at: http://localhost:8080/#/experiments/1
# 2025/11/09 17:01:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/09 17:01:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Support Vector Regression:
#   RMSE: 74502.21
#   MAE: 51817.26
#   R^2: 0.029
#   CV R^2 (mean ± std): -0.029 ± 0.068
# 🏃 View run Support Vector Regression at: http://localhost:8080/#/experiments/1/runs/ec762d64563e4f2b8b777f3884c69359
# 🧪 View experiment at: http://localhost:8080/#/experiments/1

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# I couldn't beat previous models in terms of mean absolute error and root mean squared error on test set. The best run was Gradient boosting from first configuration. Second was Extra Trees from my configuration but with this example there are higher differences for metrics on test and train dataset which means bigger overfitting than gradient boosting

# %% [markdown]
# ## 3. Manual logging with PyTorch

# %% [markdown]
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but many people prefer or often need low-level control of pure PyTorch. Thus, we will focus on this approach, which also will teach us more about powerful MLflow capabilities.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# <Experiment: artifact_location='/Users/dawidwozniak/studies/sem9/MLOps/lab05/laboratory/mlflow-artifacts/2', creation_time=1762340970784, experiment_id='2', last_update_time=1762340970784, lifecycle_stage='active', name='pytorch-housing-manual', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %% [markdown]
# ### 3.1 Targets transformation

# %% [markdown]
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them!

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model

# %% [markdown]
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())
        mse = mean_squared_error(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)
            mlflow.log_metric(f"{log_prefix}_mse", mse)
        return {"rmse": rmse, "mae": mae, "r2": r2, "mse": mse}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f} "
                f"MSE: {val_metrics['mse']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 58439.45, MAE: 47910.63 R^2: 0.527 MSE: 3415169792.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 31973.36, MAE: 24632.25 R^2: 0.832 MSE: 1022295616.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 30050.15, MAE: 20207.30 R^2: 0.865 MSE: 903011648.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 39229.29, MAE: 20803.71 R^2: 0.731 MSE: 1538937216.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 24215.84, MAE: 17280.05 R^2: 0.899 MSE: 586406848.000
#
# Cross-validation complete. Mean R^2: 0.771 (+/- 0.134)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.771 (+/- 0.134)
#
# Cross-Validation Performance:
#   R^2: 0.896
#   RMSE: 24412.20
#   MAE: 16661.92
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:8080/#/experiments/2/runs/8ee68e7da2d34bcbbfcd6861ac573db9
# 🧪 View experiment at: http://localhost:8080/#/experiments/2

# %% [markdown]
# Go to the MLflow dashboard and take a look at logged values. Focus particularly on the "Model metrics" tab, which for neural networks visualizes the progress of iterative training.

# %% [markdown]
# ### 3.3 Hyperparameter optimization with MLflow

# %% [markdown]
# Now, we will use MLflow logging and visualization capabilities to help us tune hyperparameters of neural networks. This is one of the major applications of experiment tracking frameworks. As neural networks have many hyperparameters, with complex interactions, and training them many times is very computationally intensive, we want to use human judgment, based on plots and metrics, to guide our choices in further experiments.
#
# A quick recap on main hyperparameters of MLPs:
#
# 1. **Learning rate:**
#    - typically 1e-5 to 1e-1
#    - too high: loss explodes, model diverges
#    - too low: slow convergence, might get stuck
#    - sweet spot: fast convergence to good minimum
#
# 3. **Model size** - number of hidden units here:
#    - typically 32 to 512
#    - too few: underfitting, can't capture patterns
#    - too many: overfitting, slow training, diminishing returns
#    - consider: more features need more capacity
#
# 5. **Dropout rate:**
#    - typically 0.0 to 0.5
#    - 0.0: no regularization, risk overfitting
#    - too high: underfitting, loses important information
#    - purpose: prevents over-reliance on specific neurons
#
# 7. **Batch size:**
#    - typically 16 to 128
#    - small: noisy gradients, often better generalization, slower
#    - large: stable gradients, faster training, needs more memory, may overfit
#    - trade-off: speed vs generalization
#
# 9. **Number of epochs:**
#    - too few: underfitting
#    - too many: overfitting
#    - optimal: when validation loss stops improving
#    - watch validation loss

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# Example:
#
# ```python
#
# base_config = {
#     # or any other your own architecture :) we definitely recommend to experiment by yourselves
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],
#     "num_samples": X_train.shape[0],
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# configs = {
#      {
#         "name": "first_run_or_other_your_own_meaningful_name",
#         "hidden_units": 128,
#          ...
#      },
#     {
#         "name": "second_run_or...",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     }
# }
#
# for config in configs:
#     # in python we can in elegant way merge two dicts using "|" operator - finally...
#     # old merging method {**base_config, **config} - ugly :(
#     training_config = base_config | config
#     trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
#     results = trainer.fit(X_train, y_train, X_test, y_test)
# ```
#
# or just manually and incrementally:
#
# ```python
# new_config = {
#     "name": "second_run_or...",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | config
# trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
# results = trainer.fit(X_train, y_train, X_test, y_test)
# ```

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %%
#Configs for experiments
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "input_features": X_train.shape[1],
    "num_samples": X_train.shape[0],
    "target_normalized": True,
    "k_folds": 5,
}

configs = [
    {
        "name": "smaller_model_test",
        "hidden_units": 64,  # Half of base
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "larger_model_test",
        "hidden_units": 256,  # Double of base
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "high_dropout_test",
        "hidden_units": 128,
        "dropout": 0.5,  # Much higher
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "low_dropout_test",
        "hidden_units": 128,
        "dropout": 0.05,  # Lower than base
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "high_learning_rate_test",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.1,  # Much higher
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "low_learning_rate_test",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.001,  # Much lower
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "more_epochs_test",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 300,  # Double
        "batch_size": 32,
    },
    {
        "name": "fewer_epochs_test",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 75,  # Half
        "batch_size": 32,
    },
    {
        "name": "large_batch_test",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 128,  # 4x larger
    },
    {
        "name": "small_batch_test",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 8,  # 4x smaller
    },
]

# %%
for idx, config in enumerate(configs):
    print(f"{idx + 1} / {len(configs)}: Training configuration: {config['name']}")
    training_config = base_config | config 
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# 1 / 10: Training configuration: smaller_model_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for smaller_model_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 26356.37, MAE: 19077.15 R^2: 0.904 MSE: 694658432.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 20462.15, MAE: 14769.44 R^2: 0.931 MSE: 418699616.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 26049.83, MAE: 16717.07 R^2: 0.899 MSE: 678593536.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 29642.11, MAE: 20225.41 R^2: 0.846 MSE: 878654528.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 23421.92, MAE: 16018.52 R^2: 0.906 MSE: 548586240.000
#
# Cross-validation complete. Mean R^2: 0.897 (+/- 0.028)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.897 (+/- 0.028)
#
# Cross-Validation Performance:
#   R^2: 0.859
#   RMSE: 28378.22
#   MAE: 19566.65
# Test Set Performance:
# ==================================================
# FINAL RESULTS for smaller_model_test:
#
# ==================================================
# 🏃 View run smaller_model_test at: http://localhost:8080/#/experiments/2/runs/454ec8e5da36405e8a073218c3a60303
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 2 / 10: Training configuration: larger_model_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for larger_model_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 71731.12, MAE: 51454.85 R^2: 0.287 MSE: 5145354752.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 95904.95, MAE: 83608.16 R^2: -0.508 MSE: 9197759488.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 32146.28, MAE: 24774.24 R^2: 0.846 MSE: 1033382976.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 65514.10, MAE: 38673.69 R^2: 0.249 MSE: 4292096768.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 70673.92, MAE: 58067.68 R^2: 0.140 MSE: 4994802688.000
#
# Cross-validation complete. Mean R^2: 0.203 (+/- 0.432)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.203 (+/- 0.432)
#
# Cross-Validation Performance:
#   R^2: 0.723
#   RMSE: 39761.32
#   MAE: 27309.59
# Test Set Performance:
# ==================================================
# FINAL RESULTS for larger_model_test:
#
# ==================================================
# 🏃 View run larger_model_test at: http://localhost:8080/#/experiments/2/runs/5788692a37a44dc3a3d9304cd97c38f0
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 3 / 10: Training configuration: high_dropout_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for high_dropout_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 24071.48, MAE: 16354.82 R^2: 0.920 MSE: 579436160.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27835.31, MAE: 16787.76 R^2: 0.873 MSE: 774804736.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 28094.31, MAE: 20203.75 R^2: 0.882 MSE: 789290176.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 33533.06, MAE: 22961.88 R^2: 0.803 MSE: 1124466176.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 29505.67, MAE: 19697.54 R^2: 0.850 MSE: 870584704.000
#
# Cross-validation complete. Mean R^2: 0.866 (+/- 0.038)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.866 (+/- 0.038)
#
# Cross-Validation Performance:
#   R^2: 0.813
#   RMSE: 32647.30
#   MAE: 23463.63
# Test Set Performance:
# ==================================================
# FINAL RESULTS for high_dropout_test:
#
# ==================================================
# 🏃 View run high_dropout_test at: http://localhost:8080/#/experiments/2/runs/cfc1468f3f9c40bc983686f5110e5e19
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 4 / 10: Training configuration: low_dropout_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for low_dropout_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 31529.13, MAE: 21197.03 R^2: 0.862 MSE: 994085952.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 45405.18, MAE: 31553.37 R^2: 0.662 MSE: 2061630208.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 40773.73, MAE: 28868.30 R^2: 0.752 MSE: 1662496896.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 56938.66, MAE: 43054.59 R^2: 0.433 MSE: 3242010368.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 64355.84, MAE: 51254.36 R^2: 0.287 MSE: 4141674496.000
#
# Cross-validation complete. Mean R^2: 0.599 (+/- 0.211)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.599 (+/- 0.211)
#
# Cross-Validation Performance:
#   R^2: 0.880
#   RMSE: 26182.50
#   MAE: 18836.32
# Test Set Performance:
# ==================================================
# FINAL RESULTS for low_dropout_test:
#
# ==================================================
# 🏃 View run low_dropout_test at: http://localhost:8080/#/experiments/2/runs/1b700d586cad47389548a16ca39aad94
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 5 / 10: Training configuration: high_learning_rate_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for high_learning_rate_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 32635.66, MAE: 22890.27 R^2: 0.852 MSE: 1065086592.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 22673.47, MAE: 15584.52 R^2: 0.916 MSE: 514086176.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 27038.88, MAE: 17581.91 R^2: 0.891 MSE: 731100864.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 25050.43, MAE: 17398.64 R^2: 0.890 MSE: 627523968.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 35662.03, MAE: 25993.69 R^2: 0.781 MSE: 1271780224.000
#
# Cross-validation complete. Mean R^2: 0.866 (+/- 0.047)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.866 (+/- 0.047)
#
# Cross-Validation Performance:
#   R^2: 0.811
#   RMSE: 32844.48
#   MAE: 21615.28
# Test Set Performance:
# ==================================================
# FINAL RESULTS for high_learning_rate_test:
#
# ==================================================
# 🏃 View run high_learning_rate_test at: http://localhost:8080/#/experiments/2/runs/596ed9b40d014390a38df01ebd2eb3fd
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 6 / 10: Training configuration: low_learning_rate_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for low_learning_rate_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 76783.48, MAE: 55641.85 R^2: 0.183 MSE: 5895704064.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 64626.16, MAE: 37396.83 R^2: 0.315 MSE: 4176540672.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 55828.34, MAE: 40788.17 R^2: 0.536 MSE: 3116803328.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 90579.71, MAE: 37488.30 R^2: -0.436 MSE: 8204684288.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 52016.58, MAE: 40138.50 R^2: 0.534 MSE: 2705724672.000
#
# Cross-validation complete. Mean R^2: 0.226 (+/- 0.357)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.226 (+/- 0.357)
#
# Cross-Validation Performance:
#   R^2: 0.445
#   RMSE: 56300.14
#   MAE: 38819.08
# Test Set Performance:
# ==================================================
# FINAL RESULTS for low_learning_rate_test:
#
# ==================================================
# 🏃 View run low_learning_rate_test at: http://localhost:8080/#/experiments/2/runs/44c8f7043dfd4a818ffe779dae01ff04
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 7 / 10: Training configuration: more_epochs_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for more_epochs_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 46886.21, MAE: 32440.54 R^2: 0.695 MSE: 2198316544.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 51105.78, MAE: 30915.55 R^2: 0.572 MSE: 2611800576.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 34784.71, MAE: 21902.26 R^2: 0.820 MSE: 1209976192.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 35356.71, MAE: 24563.56 R^2: 0.781 MSE: 1250096768.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 47191.75, MAE: 28023.78 R^2: 0.617 MSE: 2227060992.000
#
# Cross-validation complete. Mean R^2: 0.697 (+/- 0.094)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.697 (+/- 0.094)
#
# Cross-Validation Performance:
#   R^2: 0.769
#   RMSE: 36320.43
#   MAE: 26077.44
# Test Set Performance:
# ==================================================
# FINAL RESULTS for more_epochs_test:
#
# ==================================================
# 🏃 View run more_epochs_test at: http://localhost:8080/#/experiments/2/runs/dc31484d87e7422dad2244d5652c5684
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 8 / 10: Training configuration: fewer_epochs_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for fewer_epochs_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 69494.77, MAE: 57243.89 R^2: 0.331 MSE: 4829523968.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44323.10, MAE: 36595.77 R^2: 0.678 MSE: 1964537344.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 84730.96, MAE: 61057.33 R^2: -0.070 MSE: 7179335680.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 87240.69, MAE: 55875.19 R^2: -0.332 MSE: 7610937856.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 118585.54, MAE: 98169.59 R^2: -1.421 MSE: 14062529536.000
#
# Cross-validation complete. Mean R^2: -0.163 (+/- 0.717)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -0.163 (+/- 0.717)
#
# Cross-Validation Performance:
#   R^2: -0.111
#   RMSE: 79659.23
#   MAE: 57471.81
# Test Set Performance:
# ==================================================
# FINAL RESULTS for fewer_epochs_test:
#
# ==================================================
# 🏃 View run fewer_epochs_test at: http://localhost:8080/#/experiments/2/runs/5eaf6428c11a412aa53b3c9af62f6bf0
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 9 / 10: Training configuration: large_batch_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for large_batch_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 153860.05, MAE: 126241.60 R^2: -2.280 MSE: 23672913920.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 136302.95, MAE: 102413.00 R^2: -2.045 MSE: 18578493440.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 85454.82, MAE: 72665.31 R^2: -0.088 MSE: 7302525952.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 57112.43, MAE: 36121.38 R^2: 0.429 MSE: 3261829888.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 99210.93, MAE: 86863.45 R^2: -0.695 MSE: 9842808832.000
#
# Cross-validation complete. Mean R^2: -0.936 (+/- 1.066)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -0.936 (+/- 1.066)
#
# Cross-Validation Performance:
#   R^2: 0.308
#   RMSE: 62886.29
#   MAE: 50024.72
# Test Set Performance:
# ==================================================
# FINAL RESULTS for large_batch_test:
#
# ==================================================
# 🏃 View run large_batch_test at: http://localhost:8080/#/experiments/2/runs/ee90416758714b6a9310049036a624dc
# 🧪 View experiment at: http://localhost:8080/#/experiments/2
# 10 / 10: Training configuration: small_batch_test
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for small_batch_test...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 56502.33, MAE: 30721.75 R^2: 0.558 MSE: 3192513280.000
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 24848.07, MAE: 17786.82 R^2: 0.899 MSE: 617426560.000
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 37445.86, MAE: 22757.38 R^2: 0.791 MSE: 1402192768.000
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 28131.79, MAE: 18434.03 R^2: 0.861 MSE: 791397696.000
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 62496.64, MAE: 40319.90 R^2: 0.328 MSE: 3905830400.000
#
# Cross-validation complete. Mean R^2: 0.687 (+/- 0.215)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.687 (+/- 0.215)
#
# Cross-Validation Performance:
#   R^2: 0.809
#   RMSE: 33025.95
#   MAE: 22869.99
# Test Set Performance:
# ==================================================
# FINAL RESULTS for small_batch_test:
#
# ==================================================
# 🏃 View run small_batch_test at: http://localhost:8080/#/experiments/2/runs/a80c555251ac4c0f96045a08ed3e21ee
# 🧪 View experiment at: http://localhost:8080/#/experiments/2

# %% [markdown]
# ![image.png](attachment:image.png)
#
# I couldn't beat first run and all of my experiments got overfitted or underfitted. Underfitting happens with low epoch size or low learning rate which makes that model didn't converge, can be observed via R-squared parameter which is low or even lower than 0. It's theoretically possible and means that our model explains data worse than just using a median from data. Other sensitive parameter was model size, and increasing that makes overfitting even greater. Parameter tuning is not an easy task, maybe using tool for automatic hyperparameter tuning like [Optuna](https://github.com/optuna/optuna) can be helpful. Maybe more focus should be spent on analyzing dataset, maybe some column can be removed which can help in overall model performance.
#
# In comparison with first scikit learn and pytorch configuration I see that both configurations overfit. They get similar root mean squared error on test dataset: 21600 (sklearn) vs 24412 (pytorch) but pytorch gets much lower root mean squared error on train dataset: 11740 (sklearn) vs 0.135 (pytorch) from which we can conclude that first pytorch configuration overfits more than sklearn configuration.
#
# **Note** For pytorch run, final metric on test dataset was mean squared error, and same on sklearn for training there was mean squared error so I applied root on that metrics to have it same dimension and can compare it straightforward (there was option to apply root to mean squared error or square to root mean squared error.)
